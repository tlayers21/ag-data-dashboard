# %%
import requests
import pandas as pd

# USDA API Key
API_KEY = "GA0LAyk7zcLgEjKMdSfOIOl7GJmL4wRleIlflcfp"

# Base URL
BASE_URL = "https://api.fas.usda.gov"

# Parameters for requests
params = {"api_key": API_KEY}

# %%
commodity_code = "0440000"
country_code = "US"
market_year = "2025"

ENDPOINT = f"/api/psd/commodity/{commodity_code}/country/{country_code}/year/{market_year}"

response = requests.get(BASE_URL + ENDPOINT, params=params)
data = pd.DataFrame(response.json())
data
# Out:
#    commodityCode countryCode marketYear calendarYear month  attributeId  \
# 0        0440000          US       2025         2025    12            4
# 1        0440000          US       2025         2025    12           20
# 2        0440000          US       2025         2025    12           28
# 3        0440000          US       2025         2025    12           57
# 4        0440000          US       2025         2025    12           81
# 5        0440000          US       2025         2025    12           84
# 6        0440000          US       2025         2025    12           86
# 7        0440000          US       2025         2025    12           88
# 8        0440000          US       2025         2025    12          113
# 9        0440000          US       2025         2025    12          130
# 10       0440000          US       2025         2025    12          192
# 11       0440000          US       2025         2025    12          125
# ...

# %%
# PSD DATA
psd_response = requests.get(BASE_URL + ENDPOINT, params=params)
psd = pd.DataFrame(psd_response.json())

# ATTRIBUTE TABLE
attr_endpoint = "/api/psd/commodityAttributes"
attr_response = requests.get(BASE_URL + attr_endpoint, params=params)
attributes = pd.DataFrame(attr_response.json())

def decipher_attribute(code: int) -> str:
    row = attributes[attributes["attributeId"] == code]
    return row["attributeName"].iloc[0] if not row.empty else "Unknown attributeId"

print(decipher_attribute(4))
print(decipher_attribute(20))
print(decipher_attribute(28))
print(decipher_attribute(57))
print(decipher_attribute(81))
print(decipher_attribute(84))
print(decipher_attribute(86))
print(decipher_attribute(88))
print(decipher_attribute(113))
print(decipher_attribute(130))
print(decipher_attribute(192))
print(decipher_attribute(125))
print(decipher_attribute(176))
print(decipher_attribute(178))
print(decipher_attribute(184))
# Out:
# Area Harvested
# Beginning Stocks
# Production
# Imports
# TY Imports
# TY Imp. from U.S.
# Total Supply
# Exports
# TY Exports
# Feed Dom. Consumption
# FSI Consumption
# Domestic Consumption
# Ending Stocks
# Total Distribution
# Yield

# %%
commodity_code = "2222000"
country_code = "US"
market_year = "2025"

ENDPOINT = f"/api/psd/commodity/{commodity_code}/country/{country_code}/year/{market_year}"

response = requests.get(BASE_URL + ENDPOINT, params=params)
data = pd.DataFrame(response.json())
data
# Out:
#    commodityCode countryCode marketYear calendarYear month  attributeId  \
# 0        2222000          US       2025         2025    12            4
# 1        2222000          US       2025         2025    12           20
# 2        2222000          US       2025         2025    12           28
# 3        2222000          US       2025         2025    12           57
# 4        2222000          US       2025         2025    12           86
# 5        2222000          US       2025         2025    12           88
# 6        2222000          US       2025         2025    12            7
# 7        2222000          US       2025         2025    12          149
# 8        2222000          US       2025         2025    12          161
# 9        2222000          US       2025         2025    12          125
# 10       2222000          US       2025         2025    12          176
# 11       2222000          US       2025         2025    12          178
# ...

# %%
print(decipher_attribute(4))
print(decipher_attribute(20))
print(decipher_attribute(28))
print(decipher_attribute(57))
print(decipher_attribute(86))
print(decipher_attribute(88))
print("7", decipher_attribute(7))
print("149", decipher_attribute(149))
print("161", decipher_attribute(161))
print(decipher_attribute(125))
print(decipher_attribute(176))
print(decipher_attribute(178))
print(decipher_attribute(184))
# Out:
# Area Harvested
# Beginning Stocks
# Production
# Imports
# Total Supply
# Exports
# 7 Crush
# 149 Food Use Dom. Cons.
# 161 Feed Waste Dom. Cons.
# Domestic Consumption
# Ending Stocks
# Total Distribution
# Yield

# %%
commodity_code = "0813100"
country_code = "US"
market_year = "2025"

ENDPOINT = f"/api/psd/commodity/{commodity_code}/country/{country_code}/year/{market_year}"

response = requests.get(BASE_URL + ENDPOINT, params=params)
data = pd.DataFrame(response.json())
data
# Out:
#    commodityCode countryCode marketYear calendarYear month  attributeId  \
# 0        0813100          US       2025         2025    12            7
# 1        0813100          US       2025         2025    12          181
# 2        0813100          US       2025         2025    12           20
# 3        0813100          US       2025         2025    12           28
# 4        0813100          US       2025         2025    12           57
# 5        0813100          US       2025         2025    12           86
# 6        0813100          US       2025         2025    12           88
# 7        0813100          US       2025         2025    12          140
# 8        0813100          US       2025         2025    12          149
# 9        0813100          US       2025         2025    12          161
# 10       0813100          US       2025         2025    12          125
# 11       0813100          US       2025         2025    12          176
# ...

# %%
print("140", decipher_attribute(140))
print("181", decipher_attribute(181))
print("194", decipher_attribute(194))
# Out:
# 140 Industrial Dom. Cons.
# 181 Extr. Rate, 999.9999
# 194 SME

# %%
commodity_code = "4232000"
country_code = "US"
market_year = "2025"

ENDPOINT = f"/api/psd/commodity/{commodity_code}/country/{country_code}/year/{market_year}"

response = requests.get(BASE_URL + ENDPOINT, params=params)
data = pd.DataFrame(response.json())
data
# Out:
#    commodityCode countryCode marketYear calendarYear month  attributeId  \
# 0        4232000          US       2025         2025    12            7
# 1        4232000          US       2025         2025    12          181
# 2        4232000          US       2025         2025    12           20
# 3        4232000          US       2025         2025    12           28
# 4        4232000          US       2025         2025    12           57
# 5        4232000          US       2025         2025    12           86
# 6        4232000          US       2025         2025    12           88
# 7        4232000          US       2025         2025    12          140
# 8        4232000          US       2025         2025    12          149
# 9        4232000          US       2025         2025    12          161
# 10       4232000          US       2025         2025    12          125
# 11       4232000          US       2025         2025    12          176
# ...

# %%
commodity_code = "0410000"
country_code = "US"
market_year = "2025"

ENDPOINT = f"/api/psd/commodity/{commodity_code}/country/{country_code}/year/{market_year}"

response = requests.get(BASE_URL + ENDPOINT, params=params)
data = pd.DataFrame(response.json())
print(data.dtypes)
data
# Out:
# commodityCode     object
# countryCode       object
# marketYear        object
# calendarYear      object
# month             object
# attributeId        int64
# unitId             int64
# value            float64
# dtype: object
#    commodityCode countryCode marketYear calendarYear month  attributeId  \
# 0        0410000          US       2025         2025    12            4
# 1        0410000          US       2025         2025    12           20
# 2        0410000          US       2025         2025    12           28
# 3        0410000          US       2025         2025    12           57
# 4        0410000          US       2025         2025    12           81
# 5        0410000          US       2025         2025    12           84
# 6        0410000          US       2025         2025    12           86
# 7        0410000          US       2025         2025    12           88
# 8        0410000          US       2025         2025    12          113
# ...

# %%
commodity_code = "0410000"
market_year = "2025"

ENDPOINT = f"/api/psd/commodity/{commodity_code}/country/all/year/{market_year}"

response = requests.get(BASE_URL + ENDPOINT, params=params)
data = pd.DataFrame(response.json())
us_data = data[data["countryCode"] == "US"]
us_data
# Out:
#      commodityCode countryCode marketYear calendarYear month  attributeId  \
# 1710       0410000          US       2025         2025    12            4
# 1711       0410000          US       2025         2025    12           20
# 1712       0410000          US       2025         2025    12           28
# 1713       0410000          US       2025         2025    12           57
# 1714       0410000          US       2025         2025    12           81
# 1715       0410000          US       2025         2025    12           84
# 1716       0410000          US       2025         2025    12           86
# 1717       0410000          US       2025         2025    12           88
# 1718       0410000          US       2025         2025    12          113
# 1719       0410000          US       2025         2025    12          130
# 1720       0410000          US       2025         2025    12          192
# 1721       0410000          US       2025         2025    12          125
# ...

# %%
commodity_code = "0440000"
market_year = "2025"

ENDPOINT = f"/api/psd/commodity/{commodity_code}/world/year/{market_year}"

response = requests.get(BASE_URL + ENDPOINT, params=params)
data = pd.DataFrame(response.json())
data
# Out:
#    commodityCode countryCode marketYear calendarYear month  attributeId  \
# 0        0440000          00       2025         2025    12            4
# 1        0440000          00       2025         2025    12           20
# 2        0440000          00       2025         2025    12           28
# 3        0440000          00       2025         2025    12           57
# 4        0440000          00       2025         2025    12           81
# 5        0440000          00       2025         2025    12           84
# 6        0440000          00       2025         2025    12           86
# 7        0440000          00       2025         2025    12           88
# 8        0440000          00       2025         2025    12          113
# 9        0440000          00       2025         2025    12          130
# 10       0440000          00       2025         2025    12          192
# 11       0440000          00       2025         2025    12          125
# ...

# %%
commodity_code = "2222000"
market_year = "2025"

ENDPOINT = f"/api/psd/commodity/{commodity_code}/world/year/{market_year}"

response = requests.get(BASE_URL + ENDPOINT, params=params)
data = pd.DataFrame(response.json())
data
# Out:
#    commodityCode countryCode marketYear calendarYear month  attributeId  \
# 0        2222000          00       2025         2025    12            4
# 1        2222000          00       2025         2025    12           20
# 2        2222000          00       2025         2025    12           28
# 3        2222000          00       2025         2025    12           57
# 4        2222000          00       2025         2025    12           86
# 5        2222000          00       2025         2025    12           88
# 6        2222000          00       2025         2025    12            7
# 7        2222000          00       2025         2025    12          149
# 8        2222000          00       2025         2025    12          161
# 9        2222000          00       2025         2025    12          125
# 10       2222000          00       2025         2025    12          176
# 11       2222000          00       2025         2025    12          178
# ...

# %%
commodity_code = "0813100"
market_year = "2025"

ENDPOINT = f"/api/psd/commodity/{commodity_code}/world/year/{market_year}"

response = requests.get(BASE_URL + ENDPOINT, params=params)
data = pd.DataFrame(response.json())
data
# Out:
#    commodityCode countryCode marketYear calendarYear month  attributeId  \
# 0        0813100          00       2025         2025    12            7
# 1        0813100          00       2025         2025    12          181
# 2        0813100          00       2025         2025    12           20
# 3        0813100          00       2025         2025    12           28
# 4        0813100          00       2025         2025    12           57
# 5        0813100          00       2025         2025    12           86
# 6        0813100          00       2025         2025    12           88
# 7        0813100          00       2025         2025    12          140
# 8        0813100          00       2025         2025    12          149
# 9        0813100          00       2025         2025    12          161
# 10       0813100          00       2025         2025    12          125
# 11       0813100          00       2025         2025    12          176
# ...

# %%
commodity_code = "4232000"
market_year = "2025"

ENDPOINT = f"/api/psd/commodity/{commodity_code}/world/year/{market_year}"

response = requests.get(BASE_URL + ENDPOINT, params=params)
data = pd.DataFrame(response.json())
data
# Out:
#    commodityCode countryCode marketYear calendarYear month  attributeId  \
# 0        4232000          00       2025         2025    12            7
# 1        4232000          00       2025         2025    12          181
# 2        4232000          00       2025         2025    12           20
# 3        4232000          00       2025         2025    12           28
# 4        4232000          00       2025         2025    12           57
# 5        4232000          00       2025         2025    12           86
# 6        4232000          00       2025         2025    12           88
# 7        4232000          00       2025         2025    12          140
# 8        4232000          00       2025         2025    12          149
# 9        4232000          00       2025         2025    12          161
# 10       4232000          00       2025         2025    12          125
# 11       4232000          00       2025         2025    12          176
# ...

# %%
ommodity_code = "0410000"
market_year = "2025"

ENDPOINT = f"/api/psd/commodity/{commodity_code}/world/year/{market_year}"

response = requests.get(BASE_URL + ENDPOINT, params=params)
data = pd.DataFrame(response.json())
data
# Out:
#    commodityCode countryCode marketYear calendarYear month  attributeId  \
# 0        4232000          00       2025         2025    12            7
# 1        4232000          00       2025         2025    12          181
# 2        4232000          00       2025         2025    12           20
# 3        4232000          00       2025         2025    12           28
# 4        4232000          00       2025         2025    12           57
# 5        4232000          00       2025         2025    12           86
# 6        4232000          00       2025         2025    12           88
# 7        4232000          00       2025         2025    12          140
# 8        4232000          00       2025         2025    12          149
# 9        4232000          00       2025         2025    12          161
# 10       4232000          00       2025         2025    12          125
# 11       4232000          00       2025         2025    12          176
# ...

# %%
commodity_code = "0410000"
country_code = "MX"
market_year = "2025"

ENDPOINT = f"/api/psd/commodity/{commodity_code}/country/{country_code}/year/{market_year}"

response = requests.get(BASE_URL + ENDPOINT, params=params)
data = pd.DataFrame(response.json())
print(data.dtypes)
data
# Out:
# commodityCode     object
# countryCode       object
# marketYear        object
# calendarYear      object
# month             object
# attributeId        int64
# unitId             int64
# value            float64
# dtype: object
#    commodityCode countryCode marketYear calendarYear month  attributeId  \
# 0        0410000          MX       2025         2025    12            4
# 1        0410000          MX       2025         2025    12           20
# 2        0410000          MX       2025         2025    12           28
# 3        0410000          MX       2025         2025    12           57
# 4        0410000          MX       2025         2025    12           81
# 5        0410000          MX       2025         2025    12           84
# 6        0410000          MX       2025         2025    12           86
# 7        0410000          MX       2025         2025    12           88
# 8        0410000          MX       2025         2025    12          113
# ...
