# %%
import requests
import os

url = "http://www.ams.usda.gov/mnreports/wa_gr101.txt"
download_folder = "USDA_Grain_Reports"
os.makedirs(download_folder, exist_ok=True)

filename = os.path.join(download_folder, "WA_GR101_latest.txt")

r = requests.get(url)
if r.status_code == 200:
    with open(filename, "wb") as f:
        f.write(r.content)
    print(f"Downloaded latest WA_GR101 report: {filename}")
else:
    print("Failed to download the report")
# Out:
# Downloaded latest WA_GR101 report: USDA_Grain_Reports/WA_GR101_latest.txt

# %%
# Path to the downloaded TXT
filename = "USDA_Grain_Reports/WA_GR101_latest.txt"

grains_of_interest = ["CORN", "SOYBEANS", "WHEAT"]
inspection_numbers = {}

with open(filename, "r") as f:
    lines = f.readlines()

for line in lines:
    line = line.strip()
    if not line:
        continue
    parts = line.split()
    if parts[0] in grains_of_interest:
        # Only try to parse if parts[1] is a number (ignore header lines)
        if parts[1].replace(",", "").isdigit():
            current_week_number = int(parts[1].replace(",", ""))
            inspection_numbers[parts[0]] = current_week_number

print("Latest WA_GR101 weekly inspections:")
for grain, number in inspection_numbers.items():
    print(f"{grain}: {number}")
# Out:
# Latest WA_GR101 weekly inspections:
# CORN: 1206913
# SOYBEANS: 980518
# WHEAT: 183305

# %%
import os
import time
from datetime import datetime
import requests
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# ---------------- CONFIG ----------------
BASE_URL = "https://esmis.nal.usda.gov/publication/grains-inspected-export-weekly"
OUTPUT_DIR = "../data/inspections"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Browser-like headers to avoid 403
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/117.0.0.0 Safari/537.36"
}

# ---------------- SETUP SELENIUM ----------------
chrome_options = Options()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--disable-dev-shm-usage")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

txt_urls = set()  # avoid duplicates

# ---------------- LOOP PAGES 1-5 ----------------
for page_num in range(0, 37):
    page_url = f"{BASE_URL}?page={page_num-1}"  # page=0 is first page
    print(f"Loading page {page_num} ...")
    driver.get(page_url)
    time.sleep(5)  # wait for JS content

    links_elements = driver.find_elements("xpath", "//a[contains(text(), 'TXT')]")
    print(f"Found {len(links_elements)} TXT links on page {page_num}.")

    for elem in links_elements:
        href = elem.get_attribute("href")
        link_text = elem.text.strip()
        if href and "WA_GR101.TXT" in href:
            txt_urls.add(href)

driver.quit()
print(f"Total WA_GR101.TXT links found: {len(txt_urls)}")

# ---------------- DOWNLOAD FILES ----------------
for url in txt_urls:
    parts = url.split("/")
    folder_part = "_".join(parts[-3:-1])
    filename = parts[-1]
    safe_filename = f"{folder_part}_{filename}"
    output_path = os.path.join(OUTPUT_DIR, safe_filename)

    print(f"Downloading {url} -> {safe_filename} ...")
    try:
        r = requests.get(url, headers=HEADERS)
        r.raise_for_status()
        with open(output_path, "wb") as f:
            f.write(r.content)
        print("Saved successfully.")
    except requests.HTTPError as e:
        print(f"Failed to download {url}: {e}")

print("Done! All WA_GR101.TXT files from pages 1-37 are saved in:", OUTPUT_DIR)
# Out:
# Loading page 0 ...
# Found 11 TXT links on page 0.
# Loading page 1 ...
# Found 11 TXT links on page 1.
# Loading page 2 ...
# Found 11 TXT links on page 2.
# Loading page 3 ...
# Found 11 TXT links on page 3.
# Loading page 4 ...
# Found 11 TXT links on page 4.
# Loading page 5 ...
# Found 11 TXT links on page 5.
# Loading page 6 ...
# Found 11 TXT links on page 6.
# Loading page 7 ...
# Found 11 TXT links on page 7.
# Loading page 8 ...
# Found 11 TXT links on page 8.
# Loading page 9 ...
# Found 11 TXT links on page 9.
# Loading page 10 ...
# Found 11 TXT links on page 10.
# Loading page 11 ...
# Found 11 TXT links on page 11.
# Loading page 12 ...
# Found 11 TXT links on page 12.
# Loading page 13 ...
# Found 11 TXT links on page 13.
# Loading page 14 ...
# Found 11 TXT links on page 14.
# Loading page 15 ...
# Found 11 TXT links on page 15.
# Loading page 16 ...
# Found 11 TXT links on page 16.
# Loading page 17 ...
# Found 11 TXT links on page 17.
# Loading page 18 ...
# Found 11 TXT links on page 18.
# Loading page 19 ...
# Found 11 TXT links on page 19.
# Loading page 20 ...
# Found 11 TXT links on page 20.
# Loading page 21 ...
# Found 11 TXT links on page 21.
# Loading page 22 ...
# Found 11 TXT links on page 22.
# Loading page 23 ...
# Found 11 TXT links on page 23.
# Loading page 24 ...
# Found 11 TXT links on page 24.
# Loading page 25 ...
# Found 11 TXT links on page 25.
# Loading page 26 ...
# Found 11 TXT links on page 26.
# Loading page 27 ...
# Found 11 TXT links on page 27.
# Loading page 28 ...
# Found 11 TXT links on page 28.
# Loading page 29 ...
# Found 11 TXT links on page 29.
# Loading page 30 ...
# Found 11 TXT links on page 30.
# Loading page 31 ...
# Found 11 TXT links on page 31.
# Loading page 32 ...
# Found 11 TXT links on page 32.
# Loading page 33 ...
# Found 11 TXT links on page 33.
# Loading page 34 ...
# Found 11 TXT links on page 34.
# Loading page 35 ...
# Found 11 TXT links on page 35.
# Loading page 36 ...
# Found 11 TXT links on page 36.
# Total WA_GR101.TXT links found: 360
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/9s162h94j/8p58qq741/WA_GR101.TXT -> 9s162h94j_8p58qq741_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/qn59qt923/cv43pm42m/WA_GR101.TXT -> qn59qt923_cv43pm42m_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/31980594h/th83nj451/WA_GR101.TXT -> 31980594h_th83nj451_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/057427194/9593v974z/WA_GR101.TXT -> 057427194_9593v974z_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/bn999d95d/41687q969/WA_GR101.TXT -> bn999d95d_41687q969_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/08613f553/df65w210r/WA_GR101.TXT -> 08613f553_df65w210r_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/8s45r811x/sf2694798/WA_GR101.TXT -> 8s45r811x_sf2694798_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/7d279r39j/fq978s83p/WA_GR101.TXT -> 7d279r39j_fq978s83p_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/v118sc71b/pg15cc25g/WA_GR101.TXT -> v118sc71b_pg15cc25g_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/8049gw03j/kh04fc66s/WA_GR101.TXT -> 8049gw03j_kh04fc66s_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/3x8189162/dj52xt51d/WA_GR101.TXT -> 3x8189162_dj52xt51d_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/st74f663g/n8711768b/WA_GR101.TXT -> st74f663g_n8711768b_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/kh04f215f/1831cx62h/WA_GR101.TXT -> kh04f215f_1831cx62h_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/r781zd218/sx61gj161/WA_GR101.TXT -> r781zd218_sx61gj161_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/vq280r251/gb19g9080/WA_GR101.TXT -> vq280r251_gb19g9080_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/7s75fh00k/gb19g876x/WA_GR101.TXT -> 7s75fh00k_gb19g876x_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/00001s58b/x346fw91f/WA_GR101.TXT -> 00001s58b_x346fw91f_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/k930dk24p/hq37x9941/WA_GR101.TXT -> k930dk24p_hq37x9941_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/0c485j00f/s4657f58p/WA_GR101.TXT -> 0c485j00f_s4657f58p_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/ng452d219/f1882f89w/WA_GR101.TXT -> ng452d219_f1882f89w_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/d791t883h/377216221/WA_GR101.TXT -> d791t883h_377216221_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/6d571327q/hq37ws705/WA_GR101.TXT -> 6d571327q_hq37ws705_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/5425kv640/ng452201r/WA_GR101.TXT -> 5425kv640_ng452201r_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/z890sg27q/0g3553195/WA_GR101.TXT -> z890sg27q_0g3553195_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/n009wx883/tb09k206r/WA_GR101.TXT -> n009wx883_tb09k206r_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/tq57qh71f/q237kj91t/WA_GR101.TXT -> tq57qh71f_q237kj91t_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/5999q0309/1n79k073r/WA_GR101.TXT -> 5999q0309_1n79k073r_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/wh247r11z/2v23ws867/WA_GR101.TXT -> wh247r11z_2v23ws867_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/s4655v81m/zg64v013g/WA_GR101.TXT -> s4655v81m_zg64v013g_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/5d86pn09h/vm40zd608/WA_GR101.TXT -> 5d86pn09h_vm40zd608_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/vh53xv90t/4x51jk041/WA_GR101.TXT -> vh53xv90t_4x51jk041_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/mg74sj59t/zk51xc983/WA_GR101.TXT -> mg74sj59t_zk51xc983_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/2v23wd44f/3n204h69b/WA_GR101.TXT -> 2v23wd44f_3n204h69b_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/2v23xs62t/h128qf359/WA_GR101.TXT -> 2v23xs62t_h128qf359_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/sf268991d/xg94hv293/WA_GR101.TXT -> sf268991d_xg94hv293_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/3n205576v/cj82md99t/WA_GR101.TXT -> 3n205576v_cj82md99t_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/bv73dx86f/5m60sq58r/WA_GR101.TXT -> bv73dx86f_5m60sq58r_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/sf269d46c/5t34ts39s/WA_GR101.TXT -> sf269d46c_5t34ts39s_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/9880x157p/2j62tf62w/WA_GR101.TXT -> 9880x157p_2j62tf62w_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/0p097h483/qb98nq09j/WA_GR101.TXT -> 0p097h483_qb98nq09j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/k0699545c/br86c174d/WA_GR101.TXT -> k0699545c_br86c174d_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/jh344477k/fn107986h/WA_GR101.TXT -> jh344477k_fn107986h_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/4b29c436c/gt54mj114/WA_GR101.TXT -> 4b29c436c_gt54mj114_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/n296zk03q/70796v17k/WA_GR101.TXT -> n296zk03q_70796v17k_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/kk91ft486/2f75rg711/WA_GR101.TXT -> kk91ft486_2f75rg711_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/dz011m567/tq57pn46r/WA_GR101.TXT -> dz011m567_tq57pn46r_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/tq57q0460/q237k185k/WA_GR101.TXT -> tq57q0460_q237k185k_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/n296xh077/pc28b280t/WA_GR101.TXT -> n296xh077_pc28b280t_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/41689c054/qj72r178q/WA_GR101.TXT -> 41689c054_qj72r178q_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/kw52jx154/h702qt64d/WA_GR101.TXT -> kw52jx154_h702qt64d_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/8s45r547p/6w9256319/WA_GR101.TXT -> 8s45r547p_6w9256319_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/df65x3279/8336jv597/WA_GR101.TXT -> df65x3279_8336jv597_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/bv73dz32b/8k71qg92j/WA_GR101.TXT -> bv73dz32b_8k71qg92j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/p2678d26d/5x21vx64t/WA_GR101.TXT -> p2678d26d_5x21vx64t_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/gm80k436p/pz50j4541/WA_GR101.TXT -> gm80k436p_pz50j4541_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/n8711d25k/kh04gb94x/WA_GR101.TXT -> n8711d25k_kh04gb94x_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/4b29d7080/6108xc39h/WA_GR101.TXT -> 4b29d7080_6108xc39h_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/h128q9435/qz20vk914/WA_GR101.TXT -> h128q9435_qz20vk914_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/nc582d189/wp98bb28s/WA_GR101.TXT -> nc582d189_wp98bb28s_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/mp48t031n/2514p5155/WA_GR101.TXT -> mp48t031n_2514p5155_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/k069b188h/8c97ng82k/WA_GR101.TXT -> k069b188h_8c97ng82k_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/0k226x76m/wp98b509j/WA_GR101.TXT -> 0k226x76m_wp98b509j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/1c18g558v/rx915d728/WA_GR101.TXT -> 1c18g558v_rx915d728_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/np195675j/tb09m3349/WA_GR101.TXT -> np195675j_tb09m3349_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/w0894897d/nc582j83f/WA_GR101.TXT -> w0894897d_nc582j83f_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/q237j9674/jm215679d/WA_GR101.TXT -> q237j9674_jm215679d_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/wd377h14n/5712nv153/WA_GR101.TXT -> wd377h14n_5712nv153_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/vm410888f/zp38xw99f/WA_GR101.TXT -> vm410888f_zp38xw99f_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/qz20v0251/qf85pk43w/WA_GR101.TXT -> qz20v0251_qf85pk43w_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/kk91h706h/th83nm05g/WA_GR101.TXT -> kk91h706h_th83nm05g_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/cv43qh29m/f1883745r/WA_GR101.TXT -> cv43qh29m_f1883745r_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/k356bp21r/dn39zj593/WA_GR101.TXT -> k356bp21r_dn39zj593_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/kw52kb99t/br86c497b/WA_GR101.TXT -> kw52kb99t_br86c497b_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/5m60s3157/f7624p74f/WA_GR101.TXT -> 5m60s3157_f7624p74f_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/pg15d143h/q237kd44m/WA_GR101.TXT -> pg15d143h_q237kd44m_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/dj52ws89z/1544cb522/WA_GR101.TXT -> dj52ws89z_1544cb522_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/r494x520p/0r968p543/WA_GR101.TXT -> r494x520p_0r968p543_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/1257c317b/zc77v1148/WA_GR101.TXT -> 1257c317b_zc77v1148_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/v979w8245/cz30qz974/WA_GR101.TXT -> v979w8245_cz30qz974_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/nk324528t/pv63hq89s/WA_GR101.TXT -> nk324528t_pv63hq89s_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/zp38wk827/g732dg94s/WA_GR101.TXT -> zp38wk827_g732dg94s_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/tm70n6964/bk128p31d/WA_GR101.TXT -> tm70n6964_bk128p31d_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/4j03fd656/5138kx06t/WA_GR101.TXT -> 4j03fd656_5138kx06t_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/k643bs89q/sq87cm00n/WA_GR101.TXT -> k643bs89q_sq87cm00n_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/dr2709972/z890t719r/WA_GR101.TXT -> dr2709972_z890t719r_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/73666x44k/2514pc95b/WA_GR101.TXT -> 73666x44k_2514pc95b_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/1r66j9335/2n49tb11r/WA_GR101.TXT -> 1r66j9335_2n49tb11r_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/h702rn95j/2227p524f/WA_GR101.TXT -> h702rn95j_2227p524f_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/vh53x406z/05742086j/WA_GR101.TXT -> vh53x406z_05742086j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/4m90f236b/kk91fs31t/WA_GR101.TXT -> 4m90f236b_kk91fs31t_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/jq0864751/nz806j69p/WA_GR101.TXT -> jq0864751_nz806j69p_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/08614k820/sn00cw66g/WA_GR101.TXT -> 08614k820_sn00cw66g_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/f4753v92j/6682zh07k/WA_GR101.TXT -> f4753v92j_6682zh07k_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/3197zd97g/xs55n596v/WA_GR101.TXT -> 3197zd97g_xs55n596v_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/gx41nv876/qj72qh72s/WA_GR101.TXT -> gx41nv876_qj72qh72s_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/pv63hr04p/bk12b243t/WA_GR101.TXT -> pv63hr04p_bk12b243t_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/4j03dr27p/6m312f793/WA_GR101.TXT -> 4j03dr27p_6m312f793_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/9w032f17q/rj430h37f/WA_GR101.TXT -> 9w032f17q_rj430h37f_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/v692vb97z/s7527g561/WA_GR101.TXT -> v692vb97z_s7527g561_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/hx11xz98f/1r66jk32j/WA_GR101.TXT -> hx11xz98f_1r66jk32j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/kw52m3236/5999px14b/WA_GR101.TXT -> kw52m3236_5999px14b_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/sf269380t/5t34tg983/WA_GR101.TXT -> sf269380t_5t34tg983_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/d217qv23q/m613n404r/WA_GR101.TXT -> d217qv23q_m613n404r_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/02871v10h/9s162506v/WA_GR101.TXT -> 02871v10h_9s162506v_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/7s75dn385/02871499k/WA_GR101.TXT -> 7s75dn385_02871499k_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/c821h1690/ws859w64g/WA_GR101.TXT -> c821h1690_ws859w64g_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/qv33tn228/4m90gm40d/WA_GR101.TXT -> qv33tn228_4m90gm40d_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/r494w870b/8p58q2700/WA_GR101.TXT -> r494w870b_8p58q2700_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/m326m789t/m900p1503/WA_GR101.TXT -> m326m789t_m900p1503_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/pz50h605b/jw827p19h/WA_GR101.TXT -> pz50h605b_jw827p19h_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/3f463n116/s7527t228/WA_GR101.TXT -> 3f463n116_s7527t228_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/z316r884k/ft849x44p/WA_GR101.TXT -> z316r884k_ft849x44p_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/6h441m68r/v118s812j/WA_GR101.TXT -> 6h441m68r_v118s812j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/8w32t1000/gf06hw11p/WA_GR101.TXT -> 8w32t1000_gf06hw11p_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/8623jt639/cz30qp57h/WA_GR101.TXT -> 8623jt639_cz30qp57h_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/j3861z613/sj13bt87z/WA_GR101.TXT -> j3861z613_sj13bt87z_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/6h442g09x/cz30rg39h/WA_GR101.TXT -> 6h442g09x_cz30rg39h_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/m900nz807/d504rq53g/WA_GR101.TXT -> m900nz807_d504rq53g_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/8910mp50f/05743m97z/WA_GR101.TXT -> 8910mp50f_05743m97z_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/rb68zf94z/d217rr68m/WA_GR101.TXT -> rb68zf94z_d217rr68m_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/pz50jb73g/02872c10s/WA_GR101.TXT -> pz50jb73g_02872c10s_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/4f16d6386/fx71br54r/WA_GR101.TXT -> 4f16d6386_fx71br54r_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/gf06g958w/sj139930j/WA_GR101.TXT -> gf06g958w_sj139930j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/st74dj86p/s7527581h/WA_GR101.TXT -> st74dj86p_s7527581h_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/pk02cn637/00000b11k/WA_GR101.TXT -> pk02cn637_00000b11k_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/pr76ff25j/zg64tx83k/WA_GR101.TXT -> pr76ff25j_zg64tx83k_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/jw828r48j/x633gd327/WA_GR101.TXT -> jw828r48j_x633gd327_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/4m90f938b/6d570b66p/WA_GR101.TXT -> 4m90f938b_6d570b66p_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/wm119150b/tx31rw476/WA_GR101.TXT -> wm119150b_tx31rw476_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/0z709n03z/z603rp495/WA_GR101.TXT -> 0z709n03z_z603rp495_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/9z904c471/x346fg731/WA_GR101.TXT -> 9z904c471_x346fg731_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/jm216m813/707974695/WA_GR101.TXT -> jm216m813_707974695_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/df65x581h/th83nw75t/WA_GR101.TXT -> df65x581h_th83nw75t_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/r207w889d/m326nn533/WA_GR101.TXT -> r207w889d_m326nn533_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/sf26b5349/m039n392s/WA_GR101.TXT -> sf26b5349_m039n392s_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/8w32t535x/d217sp08x/WA_GR101.TXT -> 8w32t535x_d217sp08x_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/s1785836k/mk61s5091/WA_GR101.TXT -> s1785836k_mk61s5091_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/fj236k117/6682xn14n/WA_GR101.TXT -> fj236k117_6682xn14n_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/bk129h996/k356bb49c/WA_GR101.TXT -> bk129h996_k356bb49c_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/rr1730171/9s1628081/WA_GR101.TXT -> rr1730171_9s1628081_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/nk324440w/p2678k99z/WA_GR101.TXT -> nk324440w_p2678k99z_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/9880xd455/9p292048n/WA_GR101.TXT -> 9880xd455_9p292048n_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/4t64hr381/x633g396x/WA_GR101.TXT -> 4t64hr381_x633g396x_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/c534gp250/rj431577h/WA_GR101.TXT -> c534gp250_rj431577h_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/rr1729643/6108vq86m/WA_GR101.TXT -> rr1729643_6108vq86m_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/sx61fp64b/cc08jj14n/WA_GR101.TXT -> sx61fp64b_cc08jj14n_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/pg15cf87w/td96m345g/WA_GR101.TXT -> pg15cf87w_td96m345g_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/8336js46r/xw42q114k/WA_GR101.TXT -> 8336js46r_xw42q114k_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/wd377n32d/1544df292/WA_GR101.TXT -> wd377n32d_1544df292_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/c821gt97r/5425kk896/WA_GR101.TXT -> c821gt97r_5425kk896_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/9g5505286/69700n50p/WA_GR101.TXT -> 9g5505286_69700n50p_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/nc580t76b/df65vg480/WA_GR101.TXT -> nc580t76b_df65vg480_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/sx61gh07v/m900qp69x/WA_GR101.TXT -> sx61gh07v_m900qp69x_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/9k420p212/t722jh361/WA_GR101.TXT -> 9k420p212_t722jh361_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/m900pk715/6q183b18w/WA_GR101.TXT -> m900pk715_6q183b18w_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/6682z5024/vh53xw73c/WA_GR101.TXT -> 6682z5024_vh53xw73c_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/j3861h494/bz60f4530/WA_GR101.TXT -> j3861h494_bz60f4530_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/1g05g9972/76537z88q/WA_GR101.TXT -> 1g05g9972_76537z88q_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/6q184f937/st74fj60q/WA_GR101.TXT -> 6q184f937_st74fj60q_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/t148fr26b/f4752r06p/WA_GR101.TXT -> t148fr26b_f4752r06p_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/fj238175t/w3765692g/WA_GR101.TXT -> fj238175t_w3765692g_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/2514qh13v/pk02f895k/WA_GR101.TXT -> 2514qh13v_pk02f895k_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/5h73qm83f/08613d76n/WA_GR101.TXT -> 5h73qm83f_08613d76n_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/nk323022z/qz20tb818/WA_GR101.TXT -> nk323022z_qz20tb818_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/hm50v029j/st74cz32p/WA_GR101.TXT -> hm50v029j_st74cz32p_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/0r967z32j/5d86pt401/WA_GR101.TXT -> 0r967z32j_5d86pt401_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/b2775d553/8910mb67j/WA_GR101.TXT -> b2775d553_8910mb67j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/bg258s95w/bz60f879z/WA_GR101.TXT -> bg258s95w_bz60f879z_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/5x21vr652/2v23x572b/WA_GR101.TXT -> 5x21vr652_2v23x572b_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/8s45qv13t/x633fk188/WA_GR101.TXT -> 8s45qv13t_x633fk188_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/wp989516s/ks65j0164/WA_GR101.TXT -> wp989516s_ks65j0164_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/1v53mb791/2227p4582/WA_GR101.TXT -> 1v53mb791_2227p4582_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/6108vz91x/3f462s46z/WA_GR101.TXT -> 6108vz91x_3f462s46z_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/8g84n250h/kw52jq521/WA_GR101.TXT -> 8g84n250h_kw52jq521_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/tb09js653/bk128x68h/WA_GR101.TXT -> tb09js653_bk128x68h_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/0r968t203/4x51k808f/WA_GR101.TXT -> 0r968t203_4x51k808f_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/gq67k7635/9593vb55z/WA_GR101.TXT -> gq67k7635_9593vb55z_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/6q184081r/0c484z46c/WA_GR101.TXT -> 6q184081r_0c484z46c_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/kd17fm305/vx023655b/WA_GR101.TXT -> kd17fm305_vx023655b_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/bk12b2906/n8711h57g/WA_GR101.TXT -> bk12b2906_n8711h57g_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/m039kg55k/sx61dx56x/WA_GR101.TXT -> m039kg55k_sx61dx56x_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/zp38z670h/1g05h616d/WA_GR101.TXT -> zp38z670h_1g05h616d_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/st74ff32x/2f75t0200/WA_GR101.TXT -> st74ff32x_2f75t0200_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/nc581x70g/q237k3184/WA_GR101.TXT -> nc581x70g_q237k3184_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/qn59qt75f/vx022436j/WA_GR101.TXT -> qn59qt75f_vx022436j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/3r076119j/08613s84m/WA_GR101.TXT -> 3r076119j_08613s84m_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/m326mt11f/6q183b42z/WA_GR101.TXT -> m326mt11f_6q183b42z_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/9s162r99c/qz20vc861/WA_GR101.TXT -> 9s162r99c_qz20vc861_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/cc08kf235/8w32t5099/WA_GR101.TXT -> cc08kf235_8w32t5099_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/v692v588z/0g355f553/WA_GR101.TXT -> v692v588z_0g355f553_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/gh93jn597/ft84bb539/WA_GR101.TXT -> gh93jn597_ft84bb539_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/jd473z886/v692v8836/WA_GR101.TXT -> jd473z886_v692v8836_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/hh63t603s/8c97m1937/WA_GR101.TXT -> hh63t603s_8c97m1937_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/n583z3779/4b29bg18b/WA_GR101.TXT -> n583z3779_4b29bg18b_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/4q77hq27m/1544dm86q/WA_GR101.TXT -> 4q77hq27m_1544dm86q_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/2f75sf61r/zs25zf769/WA_GR101.TXT -> 2f75sf61r_zs25zf769_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/47429j536/rj430d32f/WA_GR101.TXT -> 47429j536_rj430d32f_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/vh53zm05r/5t34v902d/WA_GR101.TXT -> vh53zm05r_5t34v902d_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/bv73dv615/zc77vn85z/WA_GR101.TXT -> bv73dv615_zc77vn85z_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/8049h759n/b5645v20c/WA_GR101.TXT -> 8049h759n_b5645v20c_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/g445cv93x/dz0115426/WA_GR101.TXT -> g445cv93x_dz0115426_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/8c97mt20g/kp78hm976/WA_GR101.TXT -> 8c97mt20g_kp78hm976_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/4q77gc95h/ww72bz86s/WA_GR101.TXT -> 4q77gc95h_ww72bz86s_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/9880wn712/qr46rx103/WA_GR101.TXT -> 9880wn712_qr46rx103_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/hx120b77f/f4754c96x/WA_GR101.TXT -> hx120b77f_f4754c96x_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/70796g293/pg15cn432/WA_GR101.TXT -> 70796g293_pg15cn432_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/bc387k563/mg74rm66g/WA_GR101.TXT -> bc387k563_mg74rm66g_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/2514p984d/st74df91x/WA_GR101.TXT -> 2514p984d_st74df91x_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/p84196181/r781x123c/WA_GR101.TXT -> p84196181_r781x123c_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/pr76gz69w/hh63vn170/WA_GR101.TXT -> pr76gz69w_hh63vn170_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/1544dh332/zw1311115/WA_GR101.TXT -> 1544dh332_zw1311115_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/6d5714421/bc387r521/WA_GR101.TXT -> 6d5714421_bc387r521_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/cj82mr88c/3b592t13x/WA_GR101.TXT -> cj82mr88c_3b592t13x_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/08614h381/41689c79x/WA_GR101.TXT -> 08614h381_41689c79x_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/c534fv264/1v53k3121/WA_GR101.TXT -> c534fv264_1v53k3121_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/70796s25v/6h442b467/WA_GR101.TXT -> 70796s25v_6h442b467_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/sf269p771/8c97n5695/WA_GR101.TXT -> sf269p771_8c97n5695_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/4b29bq409/0p096q905/WA_GR101.TXT -> 4b29bq409_0p096q905_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/dr26z987h/dn39xd69b/WA_GR101.TXT -> dr26z987h_dn39xd69b_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/np194z07s/vd66xm81q/WA_GR101.TXT -> np194z07s_vd66xm81q_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/pv63gf56d/q237j7787/WA_GR101.TXT -> pv63gf56d_q237j7787_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/sb397f49c/pg15bm18b/WA_GR101.TXT -> sb397f49c_pg15bm18b_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/gm80jz72b/kp78hk546/WA_GR101.TXT -> gm80jz72b_kp78hk546_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/8c97n838s/tb09ks66j/WA_GR101.TXT -> 8c97n838s_tb09ks66j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/x633gk795/3b592v56x/WA_GR101.TXT -> x633gk795_3b592v56x_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/1j92hd304/2f75sf20h/WA_GR101.TXT -> 1j92hd304_2f75sf20h_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/rv043890c/6h441904b/WA_GR101.TXT -> rv043890c_6h441904b_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/cv43qr70s/gq67mn22k/WA_GR101.TXT -> cv43qr70s_gq67mn22k_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/1z40nc394/sx61g5499/WA_GR101.TXT -> 1z40nc394_sx61g5499_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/gb19gf50t/cr56p832m/WA_GR101.TXT -> gb19gf50t_cr56p832m_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/mk61rn849/3b591g30b/WA_GR101.TXT -> mk61rn849_3b591g30b_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/pc28bq25p/v118sm96n/WA_GR101.TXT -> pc28bq25p_v118sm96n_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/9593wr36d/zg64wh35s/WA_GR101.TXT -> 9593wr36d_zg64wh35s_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/h415qh46x/4x51js09n/WA_GR101.TXT -> h415qh46x_4x51js09n_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/q811md819/wm118j508/WA_GR101.TXT -> q811md819_wm118j508_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/5425n8920/4f16f151w/WA_GR101.TXT -> 5425n8920_4f16f151w_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/2514qj59p/0r9693704/WA_GR101.TXT -> 2514qj59p_0r9693704_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/x346fs966/v979ws38m/WA_GR101.TXT -> x346fs966_v979ws38m_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/8g84p989b/x920hn97c/WA_GR101.TXT -> 8g84p989b_x920hn97c_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/sx61fk41d/qf85pb94x/WA_GR101.TXT -> sx61fk41d_qf85pb94x_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/ns065b018/tq57pv53d/WA_GR101.TXT -> ns065b018_tq57pv53d_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/g445dx218/2514q2178/WA_GR101.TXT -> g445dx218_2514q2178_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/sf269283f/5425m697s/WA_GR101.TXT -> sf269283f_5425m697s_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/9z904k51v/d217s8317/WA_GR101.TXT -> 9z904k51v_d217s8317_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/pr76g537v/6h441v29h/WA_GR101.TXT -> pr76g537v_6h441v29h_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/zk51x523s/41689643h/WA_GR101.TXT -> zk51x523s_41689643h_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/mg74qs139/2227mv69k/WA_GR101.TXT -> mg74qs139_2227mv69k_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/g158d0627/kw52kt14d/WA_GR101.TXT -> g158d0627_kw52kt14d_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/t722k048w/7h14cd72j/WA_GR101.TXT -> t722k048w_7h14cd72j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/9c67xq26s/4x51jn01m/WA_GR101.TXT -> 9c67xq26s_4x51jn01m_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/7w62gk901/0k226p145/WA_GR101.TXT -> 7w62gk901_0k226p145_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/m039kx10x/k06990132/WA_GR101.TXT -> m039kx10x_k06990132_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/2n49v3548/nz8071234/WA_GR101.TXT -> 2n49v3548_nz8071234_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/3197zw98n/vt151t35j/WA_GR101.TXT -> 3197zw98n_vt151t35j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/np1957230/st74fm40n/WA_GR101.TXT -> np1957230_st74fm40n_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/kd17dj456/hd76sq63g/WA_GR101.TXT -> kd17dj456_hd76sq63g_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/p2677v75v/np194918c/WA_GR101.TXT -> p2677v75v_np194918c_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/p841b247t/np194q037/WA_GR101.TXT -> p841b247t_np194q037_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/rx914b241/p5548d085/WA_GR101.TXT -> rx914b241_p5548d085_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/cn69p0638/gt54nm05k/WA_GR101.TXT -> cn69p0638_gt54nm05k_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/4f16d3051/vm40zs381/WA_GR101.TXT -> 4f16d3051_vm40zs381_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/9w032885t/st74cx562/WA_GR101.TXT -> 9w032885t_st74cx562_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/w9506g95h/z890t916b/WA_GR101.TXT -> w9506g95h_z890t916b_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/r207wg58n/wh248j282/WA_GR101.TXT -> r207wg58n_wh248j282_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/7h149v10w/ff3659758/WA_GR101.TXT -> 7h149v10w_ff3659758_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/9g550d00z/bg259881m/WA_GR101.TXT -> 9g550d00z_bg259881m_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/7w62g626q/2227nm86z/WA_GR101.TXT -> 7w62g626q_2227nm86z_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/h415q2891/st74dg90v/WA_GR101.TXT -> h415q2891_st74dg90v_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/b27745546/bg257q763/WA_GR101.TXT -> b27745546_bg257q763_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/8623j821g/gh93h872b/WA_GR101.TXT -> 8623j821g_gh93h872b_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/js956r18s/b56452268/WA_GR101.TXT -> js956r18s_b56452268_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/rn301h57s/s4655x92j/WA_GR101.TXT -> rn301h57s_s4655x92j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/xs55nr14w/j0990q82j/WA_GR101.TXT -> xs55nr14w_j0990q82j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/gm80kf08c/0r968n85w/WA_GR101.TXT -> gm80kf08c_0r968n85w_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/5t34v1163/tm70p946q/WA_GR101.TXT -> 5t34v1163_tm70p946q_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/0c484c28x/st74dj96x/WA_GR101.TXT -> 0c484c28x_st74dj96x_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/1v53kx94g/rx914r09d/WA_GR101.TXT -> 1v53kx94g_rx914r09d_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/rb68z832x/z316qx89q/WA_GR101.TXT -> rb68z832x_z316qx89q_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/sf268t99q/nc581976d/WA_GR101.TXT -> sf268t99q_nc581976d_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/c534h2601/zs25zq14z/WA_GR101.TXT -> c534h2601_zs25zq14z_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/f1882845s/hq37wb828/WA_GR101.TXT -> f1882845s_hq37wb828_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/1544cx04x/hm50vz966/WA_GR101.TXT -> 1544cx04x_hm50vz966_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/4m90g6263/n5840563p/WA_GR101.TXT -> 4m90g6263_n5840563p_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/1544c4223/wm1184619/WA_GR101.TXT -> 1544c4223_wm1184619_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/zs25xd601/ht24wp864/WA_GR101.TXT -> zs25xd601_ht24wp864_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/37720s62b/4m90f9240/WA_GR101.TXT -> 37720s62b_4m90f9240_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/1j92gz79q/db78v306h/WA_GR101.TXT -> 1j92gz79q_db78v306h_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/5x21vz128/ff366q21m/WA_GR101.TXT -> 5x21vz128_ff366q21m_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/7w62h5600/6m313j31q/WA_GR101.TXT -> 7w62h5600_6m313j31q_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/9880x172s/w0893m936/WA_GR101.TXT -> 9880x172s_w0893m936_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/9k420f21m/2b88rd174/WA_GR101.TXT -> 9k420f21m_2b88rd174_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/xs55nq39j/k356bg26w/WA_GR101.TXT -> xs55nq39j_k356bg26w_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/tx31r536b/dn39xn75x/WA_GR101.TXT -> tx31r536b_dn39xn75x_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/0z7099754/1v53kb362/WA_GR101.TXT -> 0z7099754_1v53kb362_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/hx120c133/hq37xk304/WA_GR101.TXT -> hx120c133_hq37xk304_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/j6731h26h/gm80j771q/WA_GR101.TXT -> j6731h26h_gm80j771q_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/8623j7200/1r66j956g/WA_GR101.TXT -> 8623j7200_1r66j956g_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/f47539200/dj52wx81k/WA_GR101.TXT -> f47539200_dj52wx81k_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/2801q973r/70796241w/WA_GR101.TXT -> 2801q973r_70796241w_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/db78vn46s/6682zd12t/WA_GR101.TXT -> db78vn46s_6682zd12t_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/qr46rm396/6108vz27w/WA_GR101.TXT -> qr46rm396_6108vz27w_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/t148gn70f/k0699c57d/WA_GR101.TXT -> t148gn70f_k0699c57d_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/5712n532m/q811mj43q/WA_GR101.TXT -> 5712n532m_q811mj43q_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/bz60f909g/6t054x53v/WA_GR101.TXT -> bz60f909g_6t054x53v_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/1n79hh21r/zc77t414q/WA_GR101.TXT -> 1n79hh21r_zc77t414q_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/6108wt21k/7h14c561k/WA_GR101.TXT -> 6108wt21k_7h14c561k_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/0z70b991p/8910m6701/WA_GR101.TXT -> 0z70b991p_8910m6701_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/x633gd69w/3r076836n/WA_GR101.TXT -> x633gd69w_3r076836n_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/0z709p79h/d217rg11t/WA_GR101.TXT -> 0z709p79h_d217rg11t_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/d217sc13x/mw22wv996/WA_GR101.TXT -> d217sc13x_mw22wv996_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/00000j67p/jh344b26b/WA_GR101.TXT -> 00000j67p_jh344b26b_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/fb494z54k/3b591z706/WA_GR101.TXT -> fb494z54k_3b591z706_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/cn69p218v/df65x7231/WA_GR101.TXT -> cn69p218v_df65x7231_WA_GR101.TXT ...
# Failed to download https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/cn69p218v/df65x7231/WA_GR101.TXT: 404 Client Error: Not Found for url: https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/cn69p218v/df65x7231/WA_GR101.TXT
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/db78w316x/cv43qk65w/WA_GR101.TXT -> db78w316x_cv43qk65w_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/pz50h627c/8k71nt62j/WA_GR101.TXT -> pz50h627c_8k71nt62j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/pv63hc875/2j62tj62h/WA_GR101.TXT -> pv63hc875_2j62tj62h_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/6q183z17b/q524m1624/WA_GR101.TXT -> 6q183z17b_q524m1624_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/cc08j425p/hh63tj24m/WA_GR101.TXT -> cc08j425p_hh63tj24m_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/7d2797449/2v23w808r/WA_GR101.TXT -> 7d2797449_2v23w808r_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/pg15ck44x/7m01cr51j/WA_GR101.TXT -> pg15ck44x_7m01cr51j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/xw42p4647/cc08j953w/WA_GR101.TXT -> xw42p4647_cc08j953w_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/w6634k26p/dn39xh45c/WA_GR101.TXT -> w6634k26p_dn39xh45c_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/db78vv95z/qf85pv46c/WA_GR101.TXT -> db78vv95z_qf85pv46c_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/2b88r451s/xk81kb398/WA_GR101.TXT -> 2b88r451s_xk81kb398_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/8w32sz36s/rj431z22p/WA_GR101.TXT -> 8w32sz36s_rj431z22p_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/v692vx282/0g356514c/WA_GR101.TXT -> v692vx282_0g356514c_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/rr173797d/r207w1023/WA_GR101.TXT -> rr173797d_r207w1023_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/2227p292z/fj237g13b/WA_GR101.TXT -> 2227p292z_fj237g13b_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/zg64vv024/9k420p280/WA_GR101.TXT -> zg64vv024_9k420p280_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/5138jx87v/9306tf68t/WA_GR101.TXT -> 5138jx87v_9306tf68t_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/79409w77t/cz30rr55j/WA_GR101.TXT -> 79409w77t_cz30rr55j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/j3861v364/8336jp286/WA_GR101.TXT -> j3861v364_8336jp286_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/vd66wm14p/f47533849/WA_GR101.TXT -> vd66wm14p_f47533849_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/9019tj488/rn302h73b/WA_GR101.TXT -> 9019tj488_rn302h73b_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/bc387r920/9z904624p/WA_GR101.TXT -> bc387r920_9z904624p_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/fx71b177q/7w62fp697/WA_GR101.TXT -> fx71b177q_7w62fp697_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/gb19g4852/z316r038t/WA_GR101.TXT -> gb19g4852_z316r038t_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/2801qc40m/zp38x729t/WA_GR101.TXT -> 2801qc40m_zp38x729t_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/f4754994z/zk51x972j/WA_GR101.TXT -> f4754994z_zk51x972j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/vx022w010/gh93jd82k/WA_GR101.TXT -> vx022w010_gh93jd82k_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/m039mq50t/gq67m9527/WA_GR101.TXT -> m039mq50t_gq67m9527_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/mw22vm69v/3t946508h/WA_GR101.TXT -> mw22vm69v_3t946508h_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/445595031/xp68m679j/WA_GR101.TXT -> 445595031_xp68m679j_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/6q182s16v/wm117w530/WA_GR101.TXT -> 6q182s16v_wm117w530_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/rx914f622/gh93hp644/WA_GR101.TXT -> rx914f622_gh93hp644_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/4m90gg31m/z316rn42b/WA_GR101.TXT -> 4m90gg31m_z316rn42b_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/x346f5183/7d279v06m/WA_GR101.TXT -> x346f5183_7d279v06m_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/g445cr76n/mk61rt832/WA_GR101.TXT -> g445cr76n_mk61rt832_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/73666m981/pv63gh238/WA_GR101.TXT -> 73666m981_pv63gh238_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/tb09k292t/bn99b360m/WA_GR101.TXT -> tb09k292t_bn99b360m_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/79409s954/8336jw275/WA_GR101.TXT -> 79409s954_8336jw275_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/mw22x603m/5712p711f/WA_GR101.TXT -> mw22x603m_5712p711f_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/tx31rv488/3n2059566/WA_GR101.TXT -> tx31rv488_3n2059566_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/j9602v10j/wd376q31c/WA_GR101.TXT -> j9602v10j_wd376q31c_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/db78wc825/w6636336c/WA_GR101.TXT -> db78wc825_w6636336c_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/1257cs39h/sf26b566k/WA_GR101.TXT -> 1257cs39h_sf26b566k_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/pz50j130t/zg64vr174/WA_GR101.TXT -> pz50j130t_zg64vr174_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/1n79h965k/3b591g47h/WA_GR101.TXT -> 1n79h965k_3b591g47h_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/5h73rp475/1j92j2307/WA_GR101.TXT -> 5h73rp475_1j92j2307_WA_GR101.TXT ...
# Saved successfully.
# Downloading https://esmis.nal.usda.gov/sites/default/release-files/ns064603t/5q47rx51v/q237j1933/WA_GR101.TXT -> 5q47rx51v_q237j1933_WA_GR101.TXT ...
# Saved successfully.
# Done! All WA_GR101.TXT files from pages 1-37 are saved in: ../data/inspections

# %%
import os
import pandas as pd
import re

# ---------------- CONFIG ----------------
DATA_DIR = "../data/inspections"
OUTPUT_CSV = "../data/inspections/weekly_exports.csv"
GRAINS_OF_INTEREST = ["CORN", "SOYBEANS", "WHEAT"]

# ---------------- HELPER FUNCTION ----------------
def parse_file(filepath):
    result = {}
    try:
        with open(filepath, "r", encoding="cp1252", errors="ignore") as f:
            text = f.read()
    except Exception as e:
        print(f"Failed to read {filepath}: {e}")
        return None

    # ---------------- Extract week ending date ----------------
    date_match = re.search(r"REPORTED IN WEEK ENDING\s+([A-Z]{3} \d{2}, \d{4})", text)
    if not date_match:
        print(f"No week ending date found in {filepath}, skipping...")
        return None
    week_ending_date = pd.to_datetime(date_match.group(1))
    result["week_ending_date"] = week_ending_date

    # ---------------- Extract grains ----------------
    for grain in GRAINS_OF_INTEREST:
        # Look for a line starting with the grain name
        pattern = rf"^{grain}\s+([\d,]+)"
        match = re.search(pattern, text, re.MULTILINE)
        if match:
            try:
                result[grain] = int(match.group(1).replace(",", ""))
            except ValueError:
                result[grain] = 0
        else:
            result[grain] = 0

    return result

# ---------------- SCAN DIRECTORY ----------------
records = []
for filename in os.listdir(DATA_DIR):
    if filename.upper().endswith(".TXT"):
        filepath = os.path.join(DATA_DIR, filename)
        data = parse_file(filepath)
        if data:
            data["source_file"] = filename
            records.append(data)

# ---------------- BUILD DATAFRAME ----------------
df = pd.DataFrame(records)
df[GRAINS_OF_INTEREST] = df[GRAINS_OF_INTEREST].fillna(0)
df = df.sort_values("week_ending_date").reset_index(drop=True)

# ---------------- SAVE CSV ----------------
df.to_csv(OUTPUT_CSV, index=False)
print(f"Processed {len(df)} weeks and saved DataFrame to {OUTPUT_CSV}")
print(df.head())
# Out:
# No week ending date found in ../data/inspections/7s75dn385_02871499k_WA_GR101.TXT, skipping...
# No week ending date found in ../data/inspections/9w032885t_st74cx562_WA_GR101.TXT, skipping...
# No week ending date found in ../data/inspections/nc580t76b_df65vg480_WA_GR101.TXT, skipping...
# No week ending date found in ../data/inspections/6q182s16v_wm117w530_WA_GR101.TXT, skipping...
# Processed 355 weeks and saved DataFrame to ../data/inspections/weekly_exports.csv
#   week_ending_date     CORN  SOYBEANS   WHEAT  \
# 0       2018-12-20   996098    651181  543126
# 1       2018-12-27   913797    677679  376281
# 2       2019-01-03   501541    673172  260134
# 3       2019-01-10  1013682   1085251  545804
# 4       2019-01-17  1108119   1110713  516643
#
#                         source_file
# 0  zs25xd601_ht24wp864_WA_GR101.TXT
# 1  m900nz807_d504rq53g_WA_GR101.TXT
# 2  7h149v10w_ff3659758_WA_GR101.TXT
# 3  sf268991d_xg94hv293_WA_GR101.TXT
# 4  c534fv264_1v53k3121_WA_GR101.TXT
